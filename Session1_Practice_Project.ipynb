# %% [markdown]
# <a href="https://colab.research.google.com/github/Amol68/ML/blob/main/Session1_Practice_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Titanic dataset file path (url) has been provided to you as six different types of raw files**
#
# (a) csv
#
# (b) excel
#
# (c) json
#
# (d) html
#
# (e) tab delimit
#
# (f) semicolon delimit

# %% [markdown]
# File path of
#
# csv : https://github.com/ybifoundation/Dataset/raw/main/Titanic.csv
#
# excel : https://github.com/ybifoundation/Dataset/raw/main/Titanic.xlsx
#
# json : https://github.com/ybifoundation/Dataset/raw/main/Titanic.json
#
# html : https://github.com/ybifoundation/Dataset/raw/main/Titanic.html
#
# tab : https://github.com/ybifoundation/Dataset/raw/main/Titanic.txt
#
# semicolon : https://github.com/ybifoundation/Dataset/raw/main/Titanic%20Semicolon.csv

# %%
#import library
import pandas as pd

# %%
# importing csv file 
data = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Titanic.csv')
pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Titanic.csv')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# importing excel file

data = pd.read_excel('https://github.com/ybifoundation/Dataset/raw/main/Titanic.xlsx')
pd.read_excel('https://github.com/ybifoundation/Dataset/raw/main/Titanic.xlsx')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# importing json file

data = pd.read_json('https://github.com/ybifoundation/Dataset/raw/main/Titanic.json')
pd.read_json('https://github.com/ybifoundation/Dataset/raw/main/Titanic.json')
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
# importing html file

data = pd.read_html('https://github.com/ybifoundation/Dataset/raw/main/Titanic.html')
data
# Out:
# [          0         1          2                            3       4      5   \
#  0     pclass  survived       name                          sex     age  sibsp
#  1          1         1      Allen       Miss. Elisabeth Walton  female     29
#  2          1         1    Allison        Master. Hudson Trevor    male   0.92
#  3          1         0    Allison          Miss. Helen Loraine  female      2
#  4          1         0    Allison  Mr. Hudson Joshua Creighton    male     30
#  ...      ...       ...        ...                          ...     ...    ...
#  1305       3         0     Zabour                 Miss. Hileni  female   14.5
#  1306       3         0     Zabour                Miss. Thamine  female    NaN
#  1307       3         0   Zakarian              Mr. Mapriededer    male   26.5
#  1308       3         0   Zakarian                    Mr. Ortin    male     27
#  1309       3         0  Zimmerman                      Mr. Leo    male     29
#
# ...

# %%
#importing  text file
data = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Titanic.txt')
data
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex    age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
#  importing semicolon file
data = pd.read_csv('https://github.com/ybifoundation/Dataset/raw/main/Titanic%20Semicolon.csv',delimiter=';')
data
# Out:
#       Unnamed: 0  pclass  survived  \
# 0              0       1         1
# 1              1       1         1
# 2              2       1         0
# 3              3       1         0
# 4              4       1         0
# ...          ...     ...       ...
# 1304        1304       3         0
# 1305        1305       3         0
# 1306        1306       3         0
# 1307        1307       3         0
# 1308        1308       3         0
#
#                                                  name     sex    age  sibsp  \
# 0                       Allen, Miss. Elisabeth Walton  female  29.00      0
# 1                      Allison, Master. Hudson Trevor    male   0.92      1
# 2                        Allison, Miss. Helen Loraine  female   2.00      1
# 3                Allison, Mr. Hudson Joshua Creighton    male  30.00      1
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.00      1
# ...                                               ...     ...    ...    ...
# ...
